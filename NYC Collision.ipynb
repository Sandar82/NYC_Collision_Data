# %%
import pandas as pd
from pandas import DataFrame, read_csv, get_dummies
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
pip install seaborn matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Data Exploration and Preprocessing

# %%
df = pd.read_csv("D:\BDAT\Business Process\Project\Motor_Vehicle_Collisions_Crashes.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\sanda\AppData\Local\Temp\ipykernel_8144\1143019954.py:1: SyntaxWarning: invalid escape sequence '\B'
#   df = pd.read_csv("D:\BDAT\Business Process\Project\Motor_Vehicle_Collisions_Crashes.csv")
# C:\Users\sanda\AppData\Local\Temp\ipykernel_8144\1143019954.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("D:\BDAT\Business Process\Project\Motor_Vehicle_Collisions_Crashes.csv")

# %%
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN       NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN       NaN        NaN
# 2  11/01/2023       1:29  BROOKLYN  11230.0  40.62179 -73.970024
# 3  06/29/2022       6:55       NaN      NaN       NaN        NaN
# 4  09/21/2022      13:21       NaN      NaN       NaN        NaN
#
#                  LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                     NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                     NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2  (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
# 3                     NaN       THROGS NECK BRIDGE               NaN
# 4                     NaN          BROOKLYN BRIDGE               NaN
#
#   OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN  ...                    Unspecified
# ...

# %%
rows, cols = df.shape

print(f"Number of rows: {rows}")
print(f"Number of columns: {cols}")
# Out:
# Number of rows: 2161733
# Number of columns: 29

# %%
# Display basic information about the dataset
data_info = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2161733 entries, 0 to 2161732
# Data columns (total 29 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     object
#  1   CRASH TIME                     object
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
#  12  NUMBER OF PEDESTRIANS INJURED  int64
#  13  NUMBER OF PEDESTRIANS KILLED   int64
#  14  NUMBER OF CYCLIST INJURED      int64
#  15  NUMBER OF CYCLIST KILLED       int64
#  16  NUMBER OF MOTORIST INJURED     int64
# ...

# %%
# Show first few rows
data_preview = df.head()

# %%
# Summary statistics for numerical columns
summary_stats = df.describe()

# %%
missing_values = df.isnull().sum()

# %%
# Display data shape (number of rows and columns)
data_shape = df.shape

# %%
# Display outputs
data_info, data_preview, summary_stats, missing_values, data_shape
# Out:
# (None,
#     CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
#  0  09/11/2021       2:39       NaN      NaN       NaN        NaN
#  1  03/26/2022      11:45       NaN      NaN       NaN        NaN
#  2  11/01/2023       1:29  BROOKLYN  11230.0  40.62179 -73.970024
#  3  06/29/2022       6:55       NaN      NaN       NaN        NaN
#  4  09/21/2022      13:21       NaN      NaN       NaN        NaN
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
#  0                     NaN    WHITESTONE EXPRESSWAY         20 AVENUE
#  1                     NaN  QUEENSBORO BRIDGE UPPER               NaN
#  2  (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
#  3                     NaN       THROGS NECK BRIDGE               NaN
#  4                     NaN          BROOKLYN BRIDGE               NaN
#
#    OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
#  0             NaN  ...                    Unspecified
# ...
